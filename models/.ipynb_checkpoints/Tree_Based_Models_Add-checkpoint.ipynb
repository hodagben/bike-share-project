# %% [markdown]
# # Tree Based Models

# %% [markdown]
# In this notebook, we will model the relation between weather data and adjusted bike trips using decision tree regression model, as well as boosting algorithm based on decision trees.

# %% [markdown]
# ## Import Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set_style('whitegrid')

# %%
# import training data
bike_train = pd.read_csv('../EDA/bikeshare_train_data.csv')

# %%
# import testing data
bike_test = pd.read_csv('../EDA/bikeshare_test_data.csv')

# %%
bike_test['adj_num_trips'] = 0

# %%
# record the coefficients of polynomial regression of trend from previous notebook
trend_reg_type = 'polynomial'
intercept = 365.77928898911864
a_1 = 1.54942756e+00
a_2 = -2.91076556e-03
a_3 = 1.30275522e-06
shift = 1318.3332525370422 
# 'shift' is the amount by which we shifted the adj_num_trips in order to make all values non-negative

# %%
def cal_trend(t):
    return(intercept + a_1*t + a_2*(t**2) + a_3*(t**3))

# %%
# bike_test['time'] = np.arange(len(bike_test))
# bike_test['time'] += len(bike_train)

# %%
# bike_test['trend'] = bike_test['time'].apply(cal_trend)

# %%
# bike_train['time'] = np.arange(len(bike_train))
# bike_train['trend'] = bike_train['time'].apply(cal_trend)

# %%
sns.lineplot(x=bike_train['time'], y=bike_train['trend'], color='blue', label='poly trend on training data')
sns.lineplot(x=bike_test['time'], y=bike_test['trend'], color='orange', label='poly trend on test data')
sns.scatterplot(x=bike_test['time'], y=bike_test['num_trips'], color='green', label='actual data')
plt.legend()
plt.show()
# This shows these are correct data
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'time'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 sns.lineplot(x=bike_train['time'], y=bike_train['trend'], color='blue', label='poly trend on training data')
#       2 sns.lineplot(x=bike_test['time'], y=bike_test['trend'], color='orange', label='poly trend on test data')
#       3 sns.scatterplot(x=bike_test['time'], y=bike_test['num_trips'], color='green', label='actual data')
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:3893, in DataFrame.__getitem__(self, key)
#    3891 if self.columns.nlevels > 1:
#    3892     return self._getitem_multilevel(key)
# -> 3893 indexer = self.columns.get_loc(key)
#    3894 if is_integer(indexer):
#    3895     indexer = [indexer]
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3798, in Index.get_loc(self, key)
#    3793     if isinstance(casted_key, slice) or (
#    3794         isinstance(casted_key, abc.Iterable)
#    3795         and any(isinstance(x, slice) for x in casted_key)
#    3796     ):
#    3797         raise InvalidIndexError(key)
# -> 3798     raise KeyError(key) from err
#    3799 except TypeError:
#    3800     # If we have a listlike key, _check_indexing_error will raise
#    3801     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3802     #  the TypeError.
#    3803     self._check_indexing_error(key)
#
# KeyError: 'time'

# %%
# remove trend from testing data
bike_test['adj_num_trips'] = bike_test['num_trips'] + shift - bike_test['trend']

# %%
sns.lineplot(x=bike_train['time'], y=bike_train['adj_num_trips'], color='blue')
sns.lineplot(x=bike_test['time'], y=bike_test['adj_num_trips'], color='orange')
plt.show()
# This is clearly not okay
# We will use a linear/piece-wise linear model for trend instead

# %% [markdown]
# ## Decision Tree Regressor

# %% [markdown]
# We first build a decision tree regressor with feature set chosen from 'max_temp', 'hdd', 'total_precip'.

# %%
features = ['max_temp', 'total_precip']

# %%
# define powerset function to return all subset of a list

from itertools import chain, combinations

def powerset(iterable):
    s = list(iterable)
    return chain.from_iterable(combinations(s, r) for r in range(len(s)+1))

# %%
# In previous section, we should have added a properly modelled 'adj_num_trips' into bike_test

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
from sklearn.metrics import mean_squared_error

# %%
MAX_DEPTH = 3

# %%
for feature in powerset(features):
    feature = list(feature)
    if len(feature) > 0:
        print('Fitting tree model with feature set', feature)
        for max_depth in range(1,MAX_DEPTH+1):
            tree = DecisionTreeRegressor(max_depth = max_depth)
            tree.fit(bike_train[feature],bike_train['adj_num_trips'])
        
            # calculate the in-sample accuracy
            pred_train = tree.predict(bike_train[feature])
            print('The in-sample rmse of depth {max_depth} tree model is', np.sqrt(mean_squared_error(pred_train,bike_train['adj_num_trips'])))
            
            # calculate the out-of-sample accuracy
            pred_test = tree.predict(bike_test[feature])
            print('The in-sample rmse of depth {max_depth} tree model is', np.sqrt(mean_squared_error(pred_test,bike_test['adj_num_trips'])))
            
            # plot the in-sample and out-of-sample prediction with true values
            fig, ax = plt.subplots(1,2,figsize = (12,5))
            sns.scatterplot(x=bike_train['time'], y=bike_train['adj_num_trips'], ax=ax[0], color='blue', alpha=0.5)
            sns.scatterplot(x=bike_train['time'], y=pred_train, ax=ax[0], color='orange')
            
            sns.scatterplot(x=bike_test['time'], y=bike_test['adj_num_trips'], ax=ax[1], color='blue', alpha=0.5)
            sns.scatterplot(x=bike_test['time'], y=pred_test, ax=ax[1], color='orange') 
            
            plt.show()
            
            # plot the residue plot
            
            if len(feature) == 1:
                
                fig, ax = plt.subplots(1,2,figsize = (12,5))
                sns.scatterplot(x=bike_train[feature[0]], y=bike_train['adj_num_trips'] - pred_train, ax=ax[0], color='green')
                sns.scatterplot(x=bike_test[feature[0]], y=bike_test['adj_num_trips'] - pred_test, ax=ax[1], color='green')
                ax[0].set_title(f'Residue plot of adj_num_trips against {feature[0]} in training data')
                ax[1].set_title(f'Residue plot of adj_num_trips against {feature[0]} in testing data')
                
                plt.show()
# Out:
# Fitting tree model with feature set ['max_temp']
# The in-sample rmse of depth {max_depth} tree model is 758.0692277082771
# The in-sample rmse of depth {max_depth} tree model is 4643.815801306197
# The in-sample rmse of depth {max_depth} tree model is 648.8386037824498
# The in-sample rmse of depth {max_depth} tree model is 4622.6087493901805
# The in-sample rmse of depth {max_depth} tree model is 615.0867012876706
# The in-sample rmse of depth {max_depth} tree model is 4609.216823830855
# Fitting tree model with feature set ['total_precip']
# The in-sample rmse of depth {max_depth} tree model is 1055.43971148311
# The in-sample rmse of depth {max_depth} tree model is 4840.23362148251
# The in-sample rmse of depth {max_depth} tree model is 1028.695902764905
# The in-sample rmse of depth {max_depth} tree model is 4816.708800772643
# The in-sample rmse of depth {max_depth} tree model is 1021.5555676194283
# The in-sample rmse of depth {max_depth} tree model is 4816.719378306783
# Fitting tree model with feature set ['max_temp', 'total_precip']
# The in-sample rmse of depth {max_depth} tree model is 758.0692277082771
# The in-sample rmse of depth {max_depth} tree model is 4643.815801306197
# The in-sample rmse of depth {max_depth} tree model is 648.0540837104423
# The in-sample rmse of depth {max_depth} tree model is 4611.420137693978
# The in-sample rmse of depth {max_depth} tree model is 562.1124343833816
# The in-sample rmse of depth {max_depth} tree model is 4608.900491521521

# %%
# plot the adj_num_trips against max_temp

# %% [markdown]
# ## Gradient Boosting

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
np.sqrt(mean_squared_error(bike_train['num_trips'],np.ones(len(bike_train))*bike_train['num_trips'].mean()))
# Out:
# 1280.8522010861693

# %% [markdown]
# ## Trend vs Station Number

# %%
def get_weather_month(s):
    return(int(s.split('/')[0]))

# %%
bike_total = pd.concat([bike_train,bike_test],ignore_index=True)

# %%
bike_total['adj_num_trips'] = bike_total['num_trips'].astype('float')

# %%
sns.scatterplot(x=bike_total['Date'], y=bike_total['num_trips'])
plt.show()

# %%
# check which month was the start of the covid decrease
def get_ym(date):
    return(date[0:7])
bike_total['year-month'] = bike_total['Date'].apply(get_ym)

# %%
max_2019 = bike_total.iloc[365*2:365*3]['num_trips'].max()
max_2020 = bike_total.iloc[365*3+60:365*4]['num_trips'].max()
max_2021 = bike_total.iloc[365*4:365*5]['num_trips'].max()

# %%
bike_total.loc[365*3+60:365*4,'adj_num_trips'] *= max_2019/max_2020

# %%
bike_total.loc[365*4:365*5,'adj_num_trips'] *= max_2019/max_2021

# %%
sns.scatterplot(x=bike_total['Date'], y=bike_total['adj_num_trips'])
plt.show()

# %%
bike_total['station_count'] = np.nan

# %%
station_count = []

# %%
# import 2017 data
df = pd.read_csv('../preprocessing/bike data/raw data/All of 2017.csv')
df['Month'] = df['Departure'].apply(get_weather_month)
station_count.extend(df.groupby('Month')['Departure station'].nunique().values)
del(df)

# %%
# import 2018-2020 data
for year in range(2018,2024):
    for month in ['January','February','March','April','May','June','July','August','September','October','November','December']:
        filepath = '../preprocessing/bike data/raw data/' + month + ' ' + str(year) + '.csv'
        df = pd.read_csv(filepath)
        station_count.append(df['Departure station'].nunique())
        del(df)
# Out:
# /var/folders/z_/vfnvng3n3hg_y07yr6f3l64w0000gn/T/ipykernel_23884/3884814474.py:5: DtypeWarning: Columns (0,1,2,3,4,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filepath)
# /var/folders/z_/vfnvng3n3hg_y07yr6f3l64w0000gn/T/ipykernel_23884/3884814474.py:5: DtypeWarning: Columns (0,1,2,3,4,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filepath)
# /var/folders/z_/vfnvng3n3hg_y07yr6f3l64w0000gn/T/ipykernel_23884/3884814474.py:5: DtypeWarning: Columns (0,1,2,3,4,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filepath)
# /var/folders/z_/vfnvng3n3hg_y07yr6f3l64w0000gn/T/ipykernel_23884/3884814474.py:5: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filepath)
# /var/folders/z_/vfnvng3n3hg_y07yr6f3l64w0000gn/T/ipykernel_23884/3884814474.py:5: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filepath)

# %%
for month in ['January','February','March','April']:
    filepath = '../preprocessing/bike data/raw data/' + month + ' ' + '2024' + '.csv'
    df = pd.read_csv(filepath)
    station_count.append(df['Departure station'].nunique())
    del(df)

# %%
bike_total.loc[0,'station_count'] = station_count[0]
for i in bike_total.index:
    if i>0:
        bike_total.loc[i,'station_count'] = max(bike_total.loc[i-1,'station_count'], station_count[min(i//30,len(station_count)-1)])

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression()
reg.fit(bike_total.loc[bike_train.index,['station_count']],bike_total.loc[bike_train.index,'adj_num_trips'])
pred = reg.predict(bike_total[['station_count']])

# %%
sns.scatterplot(x=bike_total['Date'], y=bike_total['adj_num_trips'], color='blue', alpha=0.7)
sns.lineplot(x=bike_total['Date'], y=pred, color='orange')
plt.show()

# %%
sns.scatterplot(x=bike_total['Date'], y=bike_total['adj_num_trips']-pred, color='blue')
plt.show()

# %%
sns.scatterplot(x=bike_total['station_count'], y=bike_total['adj_num_trips'],color='blue')
plt.show()

# %%
from sklearn.metrics import mean_squared_error

# %%
# rmse
train_max_index = bike_train.index.max()
print('The rmse over the training data is', np.sqrt(mean_squared_error(bike_total.loc[:train_max_index,'adj_num_trips'],pred[:train_max_index+1])))
print('The rmse over the testing data is', np.sqrt(mean_squared_error(bike_total.loc[train_max_index+1:,'adj_num_trips'],pred[train_max_index+1:])))
# Out:
# The rmse over the training data is 1297.5408329490324
# The rmse over the testing data is 2120.885671774602

# %%
# baseline trend model
aver = bike_total.loc[:train_max_index,'adj_num_trips'].mean()
print('The baseline rmse over the training data is', np.sqrt(mean_squared_error(bike_total.loc[:train_max_index,'adj_num_trips'],aver*np.ones(len(bike_train)))))
print('The baseline rmse over the testing data is', np.sqrt(mean_squared_error(bike_total.loc[train_max_index+1:,'adj_num_trips'],aver*np.ones(len(bike_test)))))
# Out:
# The baseline rmse over the training data is 1359.7179047466586
# The baseline rmse over the testing data is 2482.700236553898

# %%
# overall linear model
reg = LinearRegression()
reg.fit(np.arange(len(bike_train)).reshape(-1,1),bike_total.loc[bike_train.index,'adj_num_trips'])
ol_pred_train = reg.predict(np.arange(len(bike_train)).reshape(-1,1))
ol_pred_test = reg.predict((np.arange(len(bike_test))+len(bike_train)).reshape(-1,1))
print('The overall linear model rmse over the training data is', np.sqrt(mean_squared_error(bike_total.loc[:train_max_index,'adj_num_trips'],ol_pred_train)))
print('The overall linear model rmse over the testing data is', np.sqrt(mean_squared_error(bike_total.loc[train_max_index+1:,'adj_num_trips'],ol_pred_test)))
# Out:
# The overall linear model rmse over the training data is 1328.765444288767
# The overall linear model rmse over the testing data is 2171.720682950166
